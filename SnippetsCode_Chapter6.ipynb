# %% [markdown]
# <a href="https://colab.research.google.com/github/leanpina/Pandas_Corey_Shaffer/blob/main/SnippetsCode_Chapter6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
people = {
    "first": ["Corey", "Jane", "John"],
    "last": ["Schafer", "Doe", "Doe"],
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
people['email']
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['first'] + ' ' + df['last']
# Out:
# 0    Corey Schafer
# 1         Jane Doe
# 2         John Doe
# dtype: object

# %% [markdown]
# ## Adição de uma nova coluna

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe

# %% [markdown]
# ##Apagando coluna

# %%
df.drop(columns=['first', 'last'])
# Out:
#                      email      full_name
# 0  CoreyMSchafer@gmail.com  Corey Schafer
# 1        JaneDoe@email.com       Jane Doe
# 2        JohnDoe@email.com       John Doe

# %%
df.drop(columns=['first', 'last'], inplace=True)

# %%
df
# Out:
#                      email      full_name
# 0  CoreyMSchafer@gmail.com  Corey Schafer
# 1        JaneDoe@email.com       Jane Doe
# 2        JohnDoe@email.com       John Doe

# %% [markdown]
# ## Separar uma coluna em duas

# %%
df['full_name'].str.split(' ')
# Out:
# 0    [Corey, Schafer]
# 1         [Jane, Doe]
# 2         [John, Doe]
# Name: full_name, dtype: object

# %%
df['full_name'].str.split(' ', expand=True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %% [markdown]
# ## Adicionar (append) uma nova linha ao dataset

# %%
df.append({'first' : 'Tony'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b1f41520dd1e> in <module>
# ----> 1 df.append({'first' : 'Tony'})
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    8929             if isinstance(other, dict):
#    8930                 if not ignore_index:
# -> 8931                     raise TypeError("Can only append a dict if ignore_index=True")
#    8932                 other = Series(other)
#    8933             if other.name is None and not ignore_index:
#
# TypeError: Can only append a dict if ignore_index=True

# %%
df.append({'first' : 'Tony'}, ignore_index=True)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3                      NaN            NaN   Tony      NaN

# %% [markdown]
# ## Associar (append) dataframes

# %%
people = {
    "first": ["Tony", "Stece"],
    "last": ["Stark", "Rogers"],
    "email": ["ironMan@avenge.com", 'Cap@avenge.com']
}

df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last               email
# 0   Tony   Stark  ironMan@avenge.com
# 1  Stece  Rogers      Cap@avenge.com

# %%
df.append(df2, ignore_index=True)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3       ironMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Stece   Rogers

# %%
df = df.append(df2, ignore_index=True)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3       ironMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Stece   Rogers

# %% [markdown]
# ## Apagar linhas de um dataframe

# %%
df.drop(index=4)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3       ironMan@avenge.com            NaN   Tony    Stark

# %%
df.drop(index = df[df['last'] == 'Doe'].index)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 3       ironMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Stece   Rogers

# %% [markdown]
# Para melhorar a leitura do código podemos separar o filtro aplicado ao dataframe

# %%
filt = df['last'] == 'Doe'
df.drop(index = df[filt].index)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 3       ironMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Stece   Rogers
